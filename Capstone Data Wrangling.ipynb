# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('thads2013n.txt')

# %%
df.head()
# Out:
#           CONTROL  AGE1 METRO3 REGION   LMED   FMR    L30    L50    L80  \
# 0  '100003130103'    82    '3'    '1'  73738   956  15738  26213  40322
# 1  '100006110249'    50    '5'    '3'  55846  1100  17165  28604  45744
# 2  '100006370140'    53    '5'    '3'  55846  1100  13750  22897  36614
# 3  '100006520140'    67    '5'    '3'  55846   949  13750  22897  36614
# 4  '100007130148'    26    '1'    '3'  60991   737  14801  24628  39421
#
#     IPOV    ...          FMTINCRELFMRCAT  FMTCOST06RELAMICAT  \
# 0  11067    ...          '1 LTE 50% FMR'    '2 30 - 50% AMI'
# 1  24218    ...               '3 GT FMR'    '4 60 - 80% AMI'
# 2  15470    ...      '2 50.1 - 100% FMR'    '4 60 - 80% AMI'
# 3  13964    ...      '2 50.1 - 100% FMR'  '6 100 - 120% AMI'
# 4  15492    ...               '3 GT FMR'    '3 50 - 60% AMI'
#
#   FMTCOST08RELAMICAT  FMTCOST12RELAMICAT  FMTCOSTMEDRELAMICAT  \
# 0   '2 30 - 50% AMI'    '2 30 - 50% AMI'     '2 30 - 50% AMI'
# ...

# %%
cost6 = ['COST06RELAMIPCT','COST06RELPOVPCT', 'COST06RELFMRPCT']
cost8 = ['COST08RELAMIPCT', 'COST08RELPOVPCT', 'COST08RELFMRPCT']
cost12 = ['COST12RELAMIPCT','COST12RELPOVPCT', 'COST12RELFMRPCT']
costmed = ['COSTMedRELAMIPCT','COSTMedRELPOVPCT', 'COSTMedRELFMRPCT']
df.columns
# Out:
# Index([u'CONTROL', u'AGE1', u'METRO3', u'REGION', u'LMED', u'FMR', u'L30',
#        u'L50', u'L80', u'IPOV', u'BEDRMS', u'BUILT', u'STATUS', u'TYPE',
#        u'VALUE', u'VACANCY', u'TENURE', u'NUNITS', u'ROOMS', u'WEIGHT', u'PER',
#        u'ZINC2', u'ZADEQ', u'ZSMHC', u'STRUCTURETYPE', u'OWNRENT', u'UTILITY',
#        u'OTHERCOST', u'COST06', u'COST12', u'COST08', u'COSTMED', u'TOTSAL',
#        u'ASSISTED', u'GLMED', u'GL30', u'GL50', u'GL80', u'APLMED', u'ABL30',
#        u'ABL50', u'ABL80', u'ABLMED', u'BURDEN', u'INCRELAMIPCT',
#        u'INCRELAMICAT', u'INCRELPOVPCT', u'INCRELPOVCAT', u'INCRELFMRPCT',
#        u'INCRELFMRCAT', u'COST06RELAMIPCT', u'COST06RELAMICAT',
#        u'COST06RELPOVPCT', u'COST06RELPOVCAT', u'COST06RELFMRPCT',
#        u'COST06RELFMRCAT', u'COST08RELAMIPCT', u'COST08RELAMICAT',
#        u'COST08RELPOVPCT', u'COST08RELPOVCAT', u'COST08RELFMRPCT',
#        u'COST08RELFMRCAT', u'COST12RELAMIPCT', u'COST12RELAMICAT',
# ...

# %%
df1 = df.reindex(index = df['BUILT']).sort_index()
df1
# Out:
#               CONTROL  AGE1 METRO3 REGION   LMED   FMR    L30    L50    L80  \
# BUILT
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# 1919   '158502830133'    77    '2'    '2'  64810  1094  15553  25970  41476
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
#df[df.REGION=='4'] 0x99???
#df[df.REGION==4]
type(df.BUILT[0])
# Out:
# numpy.int64

# %%
df.groupby('REGION').count()
# Out:
#         CONTROL   AGE1  METRO3   LMED    FMR    L30    L50    L80   IPOV  \
# REGION
# '1'       16519  16519   16519  16519  16519  16519  16519  16519  16519
# '2'       17400  17400   17400  17400  17400  17400  17400  17400  17400
# '3'       19260  19260   19260  19260  19260  19260  19260  19260  19260
# '4'       11356  11356   11356  11356  11356  11356  11356  11356  11356
#
#         BEDRMS    ...      FMTINCRELFMRCAT  FMTCOST06RELAMICAT  \
# REGION            ...
# '1'      16519    ...                16519               16519
# '2'      17400    ...                17400               17400
# '3'      19260    ...                19260               19260
# '4'      11356    ...                11356               11356
#
#         FMTCOST08RELAMICAT  FMTCOST12RELAMICAT  FMTCOSTMEDRELAMICAT  \
# REGION
# '1'                  16519               16519                16519
# '2'                  17400               17400                17400
# ...

# %%
df.BUILT.value_counts().sort_index().plot()

# %%
df[df.BUILT > 2005].COST06.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST08.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST12.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COSTMED.groupby(df.BUILT).mean().plot(legend=True)

# %%
df[df.BUILT > 2005].COST06.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST08.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST12.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COSTMED.groupby(df.BUILT).median().plot(legend=True)

# %%
#Cost at 6% interest
df[df.BUILT > 2005].COST06RELFMRPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST06RELAMIPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST06RELPOVPCT.groupby(df.BUILT).mean().plot(legend=True)

# %%
df[df.BUILT > 2005].COST06RELFMRCAT.groupby([df.BUILT,df.COST06RELFMRCAT]).count().plot(kind='bar')
#how can I call multiple columns and filter?

# %%
df[df.BUILT > 2005].COST06RELFMRPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST06RELAMIPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST06RELPOVPCT.groupby(df.BUILT).median().plot(legend=True)

# %%
#Cost at 8% interest
df[df.BUILT > 2005].COST08RELFMRPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST08RELAMIPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST08RELPOVPCT.groupby(df.BUILT).mean().plot(legend=True)

# %%
df[df.BUILT > 2005].COST08RELFMRPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST08RELAMIPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST08RELPOVPCT.groupby(df.BUILT).median().plot(legend=True)

# %%
#Cost at 12%
df[df.BUILT > 2005].COST12RELFMRPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST12RELAMIPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST12RELPOVPCT.groupby(df.BUILT).mean().plot(legend=True)

# %%
df[df.BUILT > 2005].COST12RELFMRPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST12RELAMIPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST12RELPOVPCT.groupby(df.BUILT).median().plot(legend=True)

# %%
#Cost at Median interest
df[df.BUILT > 2005].COSTMedRELFMRPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COSTMedRELAMIPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COSTMedRELPOVPCT.groupby(df.BUILT).mean().plot(legend=True)

# %%
df[df.BUILT > 2005].COSTMedRELFMRPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COSTMedRELAMIPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COSTMedRELPOVPCT.groupby(df.BUILT).median().plot(legend=True)

# %%
#Cost relative to Fair Market Rent
df[df.BUILT > 2005].COST06RELFMRPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST08RELFMRPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST12RELFMRPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COSTMedRELFMRPCT.groupby(df.BUILT).mean().plot(legend=True)

# %%
#Cost relative to Fair Market Rent
df[df.BUILT > 2005].COST06RELFMRPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST08RELFMRPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST12RELFMRPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COSTMedRELFMRPCT.groupby(df.BUILT).median().plot(legend=True)

# %%
df[df.BUILT > 2005].COST06RELAMIPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST08RELAMIPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST12RELAMIPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COSTMedRELAMIPCT.groupby(df.BUILT).mean().plot(legend=True)

# %%
df[df.BUILT > 2005].COST06RELAMIPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST08RELAMIPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST12RELAMIPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COSTMedRELAMIPCT.groupby(df.BUILT).median().plot(legend=True)

# %%
#Cost relative to Poverty
df[df.BUILT > 2005].COST06RELPOVPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST08RELPOVPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COST12RELPOVPCT.groupby(df.BUILT).mean().plot(legend=True)
df[df.BUILT > 2005].COSTMedRELPOVPCT.groupby(df.BUILT).mean().plot(legend=True)

# %%
df[df.BUILT > 2005].COST06RELPOVPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST08RELPOVPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COST12RELPOVPCT.groupby(df.BUILT).median().plot(legend=True)
df[df.BUILT > 2005].COSTMedRELPOVPCT.groupby(df.BUILT).median().plot(legend=True)

# %%
df.corr().COST12RELAMIPCT.sort_values(ascending=False)
# Out:
# COST12RELAMIPCT     1.000000
# COST08RELAMIPCT     0.995166
# COST06RELAMIPCT     0.986067
# COSTMedRELAMIPCT    0.973818
# COST12RELFMRPCT     0.955375
# COST08              0.951271
# COST12              0.951013
# COST06              0.948322
# COST08RELFMRPCT     0.945901
# COSTMED             0.943349
# COST06RELFMRPCT     0.932551
# VALUE               0.919554
# COSTMedRELFMRPCT    0.915847
# COST12RELPOVPCT     0.870952
# COST08RELPOVPCT     0.865451
# COST06RELPOVPCT     0.858675
# COSTMedRELPOVPCT    0.850454
# COSTMedRELAMICAT    0.672342
# COST06RELAMICAT     0.660201
# COST08RELAMICAT     0.640110
# COST12RELAMICAT     0.596218
# ZSMHC               0.556662
# COSTMedRELFMRCAT    0.491216
# COST06RELFMRCAT     0.481817
# COST08RELFMRCAT     0.468441
# COST12RELFMRCAT     0.443542
# ZINC2               0.420007
# INCRELAMIPCT        0.413161
# OTHERCOST           0.410460
# INCRELPOVPCT        0.406119
#                       ...
# ABL50               0.290484
# ...
